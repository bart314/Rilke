# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

import numpy as np
import pickle as pkl
import logging

from utils import *
# Out:
# Bitte wählen Sie eine Synoniem für Abbildung
# [1] Zeichnung
# [2] Skizze
# [3] bildliche_Darstellung
# [4] schematische_Darstellung
# [5] ikonografischen
# [6] gestochen_scharf
# [7] Abbild
# [8] abgebildet
# [9] Darstellungsart
# [10] Abbildungen
# Ihre Wähl: 9
# Darstellungsart

# %%
logging.basicConfig(filename='network.log', filemode='w', format='%(name)s - %(levelname)s - %(message)s', level=logging.INFO)

model = load_model('files/rilke_model.h5')

# %%
tokenizer = Tokenizer(lower=False)
data = ''
for i in range(1,11):
    data += open(f'data/el{i}.txt','r').read()
corpus = data.split('\n')

tokenizer.fit_on_texts(corpus)

total_words = len(tokenizer.word_index) + 1 # for OOV token
logging.info (f'The total of different words in the corpus is {total_words}')

# %%
lengtes = [10, 7, 5, 8, 13, 6, 9, 7, 7, 12]
max_sequence_len = 13 
elegie_length = np.random.choice(lengtes) 
logging.info (f"Creating an elegie with {elegie_length} strophes.")

# %%
for s in range(elegie_length):     
    s_length = get_strophe_length()
    line = get_seed_word() 
    logging.info (f'Strophe with {s_length} lines, using {line} as start word...')
    for _ in range(s_length):
        l_length = get_line_length()
        logging.info (f'line with a length of {l_length} words...')

        for w in range(l_length):
            token_list = tokenizer.texts_to_sequences([line])[0]
            token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
            #predicted = model.predict_classes(token_list, verbose=0)
            predicted = np.argmax(model.predict(token_list), axis=-1)
            output_word = ''

            #reverse look-up
            for word, index in tokenizer.word_index.items():
                if index == predicted:
                    output_word = word
                    break
                    
            
                if line.split()[w-1] == output_word:
                    try :
                        output_word = get_synoniem(output_word)
                    except e:
                        pass
                    
            line += ' ' + output_word
            
        line += "\n"
    print (line)
# Out:
# Preise mit dem ich beinah ganz
#  überschlägst Toten zu dir Menschen ihn die vielleicht
#  sie
#  Herz sind – ihn ihn ihn ihn
#  will dir das reine Zuwenig wär er ein
#  Knabe und dürft es noch werden und säße säße säße der
#  Sohn – der Handlung kaum Wehende zu war sind
#  die gestalteten am Sohn eines Jüngling was weiß er
#  angeht hinaussah seine zerbrochenes durch dich
#  recht doch mit der eine Antwort –
#  und dann der Jüngling – ihn neugierig hinaussah ihn
#  ihn ihn eines muteten manche manche wem – und
#  die muteten manche als Toten wehe
#  dem
#  Welt O der noch bei stand ihn im Tasse und
#  im stand und noch in den
#  Falten des andern anderer Gestirn und im sprachlosen Herzen –
#  der gemeinsam kaum wie der gebognes hinein der Erde kaum wär
#  er ein Sohn – und mit
#  sich im Fenster Haustür eh dir ihn im Absprung Und
#  das dann uns hinüber zu sein Dauern
#  Und du rein wir bezog so
#
# Ach da war keine Vorsicht im Schlafenden schlafend schon
#  zu dir dir nicht nur die ihr im
#  Entzücken der ersten Heimat stand du ihn nicht die
#  Schwindendsten Einmal und der ersten Antwort Erst der Untergang
#  war ihm der liebes oft den mit der eine
#  Jüngling und ihn im kommt – und
#  mit dem wo das Wehende er der
#
# Würfen die dann ihre letzten immer ersparten voll Zukunft – der mit
#  dem Einsamen oft ihm ihn die Jahreszeit aufhebt die dem
#  beinah vergessend Erst Puppe Baum der noch –
#  und dann der
#  gebognes einen Nackens war der Untergang war diese mit der mit
#  aber an einer ihn ihn ihren künftigen wohl – ihn
#  wenige Aber das er – das noch
#  ältere Und voll
#
# O und die Nacht die Nacht wenn der
#  Wind voller Weltraum der Nackens war ihm
#  ihn die Jahreszeit entschlossene Frucht merken es
#  schon die auf um Linos oft oft Nacht dieses
#  der Sohn König dann sinds der Wind
#  dort Aber der junge der Mann um er verstrickt war
#  wie der Götter und ihn ihn ihn Doch dennoch
#  noch ihn am nächtlichen vor das noch noch oft
